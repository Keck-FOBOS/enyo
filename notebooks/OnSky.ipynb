# %%
from enyo.etc.source import OnSkyGaussian, OnSkySersic
from matplotlib import pyplot
import numpy

# %%
t = OnSkyGaussian(20, sampling=1, size=100)

# %%
pyplot.imshow(t.data, origin='lower', interpolation='nearest')

# %%
numpy.sum(t.data)
# Out:
# 0.9999999946156561

# %%
t = OnSkySersic(1.0, 50, 1, unity_integral=True, sampling=1, size=1000)

# %%
pyplot.imshow(numpy.log10(t.data), origin='lower', interpolation='nearest')
pyplot.colorbar()

# %%
numpy.sum(t.data)
# Out:
# 1.00000103015367
